# %%
import os
import music21 as m21
import regex as re 
import pandas as pd 
import numpy as np

# %%
import utils.visualization as vis

# %%
import utils.clean_data as clean

# %%
df=clean.cleaned()

# %%
df
# Out:
#                  Name   key.Key       Key Tonic Key Signature  \
# canons     0     c159   F major   F major     F       F major
#            1     c161   C major   C major     C       C major
#            2     c162  B- major  B- major    B-      B- major
#            3     c163   f minor   F minor     F       f minor
#            4     c164   C major   C major     C       C major
# ...               ...       ...       ...   ...           ...
# symphonies 30  sym8_4   F major   F major     F       F major
#            31  sym9_1   d minor   D minor     D       d minor
#            32  sym9_2   d minor   D minor     D       d minor
#            33  sym9_3  B- major  B- major    B-      B- major
#            34  sym9_4   D major   D major    B-      B- major
#
#                     Key Signatures   Tonics First Chord's Root Key Deduced 1  \
# canons     0    (F major, d minor)   (F, D)                  A          None
# ...

# %%
vis.deducible_keys(df)

# %%
vis.deducible_keys_barplot(df)

# %%
vis.key_eq_keySig(df)

# %%
vis.k_kS_ded(df)

# %%
vis.key_eq_Ded1(df)

# %%
vis.key_counts(df)

# %%
vis.major_works(df)

# %%
#restart kernel

# %%
vis.major_works_keyDed(df)

# %%
#I need to restart kernel for this plot. No time tonight. 
#vis.keys_fDs_barplot(df)

# %%
vis.rareKw_plot(df)

# %%
vis.my_pie()
